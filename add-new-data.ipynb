# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
root_dir = "/content/drive/MyDrive/cs410/data"

# %%
NUM_NEW_SUBJECTS = 6

# %%
NUM_SESSIONS_PER_SUBJECT = 6 * [1] # specify the number of sessions per subject

# %%
# if num sessions per subject > 1 and adding to existing subject:
subject_idx = -1
session_idx = -1
new_session = (subject_idx, session_idx)

# %%
latest_subject_index = 7

# %%
print(f"created {NUM_NEW_SUBJECTS} subject directories: with the following session counts:\n {NUM_SESSIONS_PER_SUBJECT}")
# Out:
# created 6 subject directories: with the following session counts:
#  [1, 1, 1, 1, 1, 1]

# %% [markdown]
# do not run the cell below

# %%
# create new subjects and subdirs
for i in range(NUM_NEW_SUBJECTS):

  if (subject_idx != -1):
    new_session = (subject_idx + 1, session_idx + 1)



  idx = latest_subject_index + 1
  subject_dir = f"{root_dir}/subject_{idx}"
  os.mkdir(subject_dir)
